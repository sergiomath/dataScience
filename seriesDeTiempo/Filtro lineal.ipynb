# %% [markdown]
# # Filtro lineal Invariante

# %% [markdown]
# $$X_t = \sum^k_{j=-k}a_jZ_{t-j}$$

# %%
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import acf

# %%
###Parámetros
np.random.seed(314)
mu=0
sigma=1
n=2000
k=3
#################################
zt=np.random.normal(mu,sigma,n)
xt=[]
ak=np.random.rand(2*k+1)

for i in range(n-2*k):
    zk=zt[i:2*k+i+1]    
    xk=(ak*np.flip(zk)).sum()
    xt.append(xk)
xt=np.asanyarray(xt)
# print(xt)

# %%
acf=plot_acf(xt,adjusted=False,lags=10)

# %%
fig = plt.figure(figsize=(8,4),dpi=200)
ax = fig.add_subplot(111)
ax.plot(xt, c='red');
plt.title('Filtro Lineal Invariate Xt')
# Out:
# Text(0.5, 1.0, 'Filtro Lineal Invariate Xt')

# %%
# Out:
# 10
