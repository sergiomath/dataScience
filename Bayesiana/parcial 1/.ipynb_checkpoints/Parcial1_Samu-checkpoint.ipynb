# %%
from scipy.stats.distributions import invgamma
from scipy.stats.distributions import expon
from scipy.special import gamma

import numpy as np
import matplotlib.pyplot as plt
import math
import scipy.stats as sps
# %matplotlib inline
np.random.seed(1234)

# %%
###Cuarto punto#####

alambres=np.array( (495,541,1461,1555,1603,2201,2750,3468,3516,4319,6622,7728,13159,21194) )#media 5043.714
n=len(alambres)
s=alambres.sum()

a=33/4
b=32625
x = np.linspace(0, 10000, 10000)
preLambda=invgamma.pdf(x, a,scale=b)
posLambda=invgamma.pdf(x, a+n,scale=b+s)

plt.plot(x, preLambda, label='previa')
plt.plot(x, posLambda, label='posterior')
#Agregamos las etiquetas y añadimos una leyenda.
plt.xlabel(r'$\lambda$')
plt.ylabel('Probabilidad' )
plt.title(r"Distribución Previa y Posterior dados $\mu_0$ y $\sigma_0$")
plt.legend()
plt.savefig('previayposterior.png')
plt.show()

# %%
#punto 6 inferencia bayesiana - montecarlo
Montecarlo=invgamma.rvs(a+n,scale=b+s,size=10000)
media=np.mean(Montecarlo)
cv=np.std(Montecarlo)/media
print(round(cv,4))
ic_B_inf=np.quantile(Montecarlo, 0.025)
print(round(ic_B_inf,4))
ic_B_sup=np.quantile(Montecarlo, 0.975)
print(round(ic_B_sup,4))
# Out:
# 1077.3458782977032
# 0.2219
# 3193.3833
# 7374.5548

# %%
#inferencia frecuentista asintotica
mediaFRE=np.mean(alambres)
cvFRE=np.std(alambres,ddof=1)/mediaFRE
print(round(cvFRE,4))
cvFREinf=mediaFRE-1.959*np.std(alambres)
print(round(cvFREinf,4))
cvFREsup=mediaFRE+1.959*np.std(alambres)
print(round(cvFREsup,4))
# Out:
# 1.1441
# -5849.4636
# 15936.8922

# %%
#inferencia frecuentista bootstrap
out = []
for i in range(10000):
    y = np.random.choice(alambres, size = 14)
    out.append(np.mean(y))
out = np.array(out)
est_F2 = np.mean(out)
cv_F2 = np.std(out)/np.mean(out)
ic_F2 = np.quantile(out,q = [0.025,0.975])
print(round(est_F2,4))
print(round(cv_F2,4))
print(ic_F2)
# Out:
# 5061.4693
# 0.2953
# [2535.60357143 8320.375     ]

# %%
####Ejercicio 7 ####
np.random.seed(1234)
B=500000
posLambda=invgamma.rvs(a+n,scale=b+s,size=B)
predicPos=np.empty(B)
for i in range(B):
    predicPos[i]=np.mean(expon.rvs(scale=posLambda[i],size=1))

# %%
##Posterior
print(round(np.mean(posLambda <4000), 8))
##Predictiva posterior
print(round(np.mean(predicPos <4000),8))
# Out:
# 0.21511
# 0.570816

# %%
###Punto 8
lambada0=4000
B10=math.exp(( (a*math.log(b)-math.log(gamma(a)) ) +(math.log(gamma(a+n))-(a+n)*math.log(b+s) ))-(-n*math.log(lambada0)-(s/lambada0)))
print(B10)
# Out:
# 0.7823909597529886

# %%
##### Punto 9 y 10 

alambres1=np.array( (495,541,1461,1555,1603,2201,2750,3468,3516,4319,6622,7728,13159,21194) )#media 5043.714
n1=len(alambres1)
s1=alambres1.sum()

alambres2=np.array((294,569,766,1576,1602,2015,2166,3885,8141,10285))
n2=len(alambres2)
s2=alambres2.sum()


a=33/4
b=32625
x = np.linspace(0, 10000, 10000)

##grafico Inicial comparativo
preLambda=invgamma.pdf(x, a,scale=b)

posLambda1=invgamma.pdf(x, a+n1,scale=b+s1)
posLambda2=invgamma.pdf(x, a+n2,scale=b+s2)
plt.plot(x, preLambda, label='previa')
plt.plot(x, posLambda1, label='posterior Exp 1')
plt.plot(x, posLambda2, label='posterior Exp 2')

B=50000
np.random.seed(1234)
lambdas=invgamma.rvs(a,scale=b,size=B)
############Hipotesisi nula#############
eLambdas=np.empty(B)
i=0
for j in lambdas:
    eLambdas[i]=math.e**(-(1/j)*(s1+s2))
    i=i+1
pH0=np.mean(lambdas**(-(n1+n2))*eLambdas)
print(pH0)
###############Hipotesis alterna#########

eLambdas1=np.empty(B)
i=0
for j in lambdas:
    eLambdas1[i]=math.e**(-(1/j)*(s1))
    i=i+1
    
eLambdas2=np.empty(B)
i=0
for j in lambdas:
    eLambdas2[i]=math.e**(-(1/j)*(s2))
    i=i+1

pH1=np.mean(lambdas**(-n1)*eLambdas1)*np.mean(lambdas**(-n2)*eLambdas2)
print(pH1)
B10=math.exp(math.log(pH1)-math.log(pH0))
print(B10)

#Agregamos las etiquetas y añadimos una leyenda.
plt.xlabel(r'$\lambda$')
plt.ylabel('Probabilidad' )
plt.title(r"Distribución Previa y Posterior dados $\mu_0$ y $\sigma_0$")
plt.legend()
plt.savefig('previayposterior-9.png')
plt.show()
# Out:
# 1.577069334084886e-98
# 1.8612498129883737e-98
# 1.1801952981784105

# %%
f = plt.figure(figsize = (7,4), dpi = 400)
axes = f.add_axes([0.1,0.1,0.9,0.9])
axes.set_xlabel('t')
axes.set_ylabel('p(t|y)')
#
axes.hist(predicPos,color = '#d0d0d0', density = True)
#
t_grid = np.linspace(np.min(predicPos), np.max(predicPos), num = 1000)
#axes.plot(t_grid, st.gaussian_kde(PredicPos)(t_grid), label = 'Posterior')
#
axes.axvline(x = np.quantile(predicPos, q = [0.025]), color = '#F4143D', label = 'IC 95%', ls = '--')
axes.axvline(x = np.quantile(predicPos, q = [0.975]), color = '#F4143D', ls = '--')
axes.axvline(x = s1/n1, color = 'black', label = 't obs')
#
plt.legend(loc = 0,frameon=False)
axes.spines['top'].set_visible(False)
axes.spines['right'].set_visible(False)
plt.savefig('10uno.png')
plt.show()

# %%
f = plt.figure(figsize = (7,4), dpi = 400)
axes = f.add_axes([0.1,0.1,0.9,0.9])
axes.set_xlabel('t')
axes.set_ylabel('p(t|y)')
#
axes.hist(predicPos2,color = '#d0d0d0', density = True)
#
t_grid = np.linspace(np.min(predicPos2), np.max(predicPos2), num = 1000)
#axes.plot(t_grid, st.gaussian_kde(PredicPos)(t_grid), label = 'Posterior')
#
axes.axvline(x = np.quantile(predicPos2, q = [0.025]), color = '#F4143D', label = 'IC 95%', ls = '--')
axes.axvline(x = np.quantile(predicPos2, q = [0.975]), color = '#F4143D', ls = '--')
axes.axvline(x = s2/n2, color = 'black', label = 't obs')
#
plt.legend(loc = 0,frameon=False)
axes.spines['top'].set_visible(False)
axes.spines['right'].set_visible(False)
plt.savefig('10dos.png')
plt.show()

# %%
np.mean(np.array(predicPos) > s1/n1)
# Out:
# 0.34492

# %%
np.mean(np.array(predicPos2) > s2/n2)
# Out:
# 0.51274
